# %%
import pandas as pd
import numpy as np
data = {
'Order_ID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
'Customer_Name': ['Amara', 'Bola', None, 'Diana', 'Efua', 'Fatima', 'Grace',
None, 'Ifeoma', 'Joyce'],
'Country': ['Ghana', 'Nigeria', 'Kenya', None, 'Ghana', 'Cameroon', None,
'Kenya', 'Nigeria', 'Ghana'],
'Product': ['Laptop', 'Phone', 'Tablet', 'Laptop', None, 'Phone', 'Tablet',
'Laptop', None, 'Phone'],
'Quantity': [2, 1, None, 3, 2, None, 1, 4, 2, None],
'Price': [1500, 800, 600, 1500, None, 800, 600, 1500, None, 800],
'Delivery_Days': [3, None, 7, 5, 3, None, 6, None, 4, 5]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    Order_ID Customer_Name   Country Product  Quantity   Price  Delivery_Days
# 0       101         Amara     Ghana  Laptop       2.0  1500.0            3.0
# 1       102          Bola   Nigeria   Phone       1.0   800.0            NaN
# 2       103          None     Kenya  Tablet       NaN   600.0            7.0
# 3       104         Diana      None  Laptop       3.0  1500.0            5.0
# 4       105          Efua     Ghana    None       2.0     NaN            3.0
# 5       106        Fatima  Cameroon   Phone       NaN   800.0            NaN
# 6       107         Grace      None  Tablet       1.0   600.0            6.0
# 7       108          None     Kenya  Laptop       4.0  1500.0            NaN
# 8       109        Ifeoma   Nigeria    None       2.0     NaN            4.0
# 9       110         Joyce     Ghana   Phone       NaN   800.0            5.0

# %%
df.info()
df.describe()
df.isnull().sum()



# There are 7 columns in total (Order_ID, Customer_Name, Country, Product, Quantity, Price, and Delivery_Days)
# Customer_Name, Country, Product, and  Price have two null values each.
# Quantity and Delivery_Days have three null values each.

# %%
df['Customer_Name'] = df['Customer_Name'].fillna('Unknown')
print(df)

# I used "Unknown" to label missing customer names because it 
# prevents pipeline errors while keeping the row intact.
# Out:
#    Order_ID Customer_Name   Country Product  Quantity   Price  Delivery_Days
# 0       101         Amara     Ghana  Laptop       2.0  1500.0            3.0
# 1       102          Bola   Nigeria   Phone       1.0   800.0            NaN
# 2       103       Unknown     Kenya  Tablet       NaN   600.0            7.0
# 3       104         Diana      None  Laptop       3.0  1500.0            5.0
# 4       105          Efua     Ghana    None       2.0     NaN            3.0
# 5       106        Fatima  Cameroon   Phone       NaN   800.0            NaN
# 6       107         Grace      None  Tablet       1.0   600.0            6.0
# 7       108       Unknown     Kenya  Laptop       4.0  1500.0            NaN
# 8       109        Ifeoma   Nigeria    None       2.0     NaN            4.0
# 9       110         Joyce     Ghana   Phone       NaN   800.0            5.0

# %%
df['Quantity'] = df['Quantity'].fillna(df['Quantity'].median())
df['Price'] = df['Price'].fillna(df['Price'].median())

# I used median for both coulmns.
# Using median for null numerical values is best practice as it is robust and handles fututre datasets better.
print(df)
# Out:
#    Order_ID Customer_Name   Country Product  Quantity   Price  Delivery_Days
# 0       101         Amara     Ghana  Laptop       2.0  1500.0            3.0
# 1       102          Bola   Nigeria   Phone       1.0   800.0            NaN
# 2       103       Unknown     Kenya  Tablet       2.0   600.0            7.0
# 3       104         Diana      None  Laptop       3.0  1500.0            5.0
# 4       105          Efua     Ghana    None       2.0   800.0            3.0
# 5       106        Fatima  Cameroon   Phone       2.0   800.0            NaN
# 6       107         Grace      None  Tablet       1.0   600.0            6.0
# 7       108       Unknown     Kenya  Laptop       4.0  1500.0            NaN
# 8       109        Ifeoma   Nigeria    None       2.0   800.0            4.0
# 9       110         Joyce     Ghana   Phone       2.0   800.0            5.0

# %%
print(df['Delivery_Days'].describe())

df['Delivery_Days'] = df['Delivery_Days'].fillna(df['Delivery_Days'].median())

# With values between 3 and 7 days, there are no outliers. 
# I chose the median because delivery days are whole numbers,
# and the mean might produce an decimal, i.e (4.5 days).
# Out:
# count    7.000000
# mean     4.714286
# std      1.496026
# min      3.000000
# 25%      3.500000
# 50%      5.000000
# 75%      5.500000
# max      7.000000
# Name: Delivery_Days, dtype: float64

# %%
df['Country'] = df['Country'].fillna(df['Country'].mode()[0])
df['Product'] = df['Product'].fillna(df['Product'].mode()[0])

# I filled the missing values to avoid dropping rows and losing revenue data. 
# I used the mode because it is the standard method for category columns and preserves the dataset's natural distribution.

# %%
print(df.isnull().sum())

"""
Order_ID         0
Customer_Name    0
Country          0
Product          0
Quantity         0
Price            0
Delivery_Days    0
dtype: int64
"""
# Out:
# Order_ID         0
# Customer_Name    0
# Country          0
# Product          0
# Quantity         0
# Price            0
# Delivery_Days    0
# dtype: int64
# '\nOrder_ID         0\nCustomer_Name    0\nCountry          0\nProduct          0\nQuantity         0\nPrice            0\nDelivery_Days    0\ndtype: int64\n'

# %%
# The first problem I faced was undersanding that missing values in one column is not the same as another.
# A null in the Customer_Name column is very different from a null in Price.
# I figured out that using mean for numerical data was the safest choice and mode for category.
# I learnt how important and complex outlier detection is in data analysis.
